# %% [markdown]
# ### Imports

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Imprimindo o conteúdo do site

# %%
response = requests.get('https://g1.globo.com/')

print(response.content)
# Out:
# b'<!DOCTYPE HTML><html lang="pt-br" class> <head><meta charset="utf-8"><meta http-equiv="x-ua-compatible" content="ie=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1"><script type="text/javascript" id="CDA_AAS">\n  window.cdaaas = window.cdaaas || {};\n  window.cdaaas.SETTINGS = window.cdaaas.SETTINGS || {};\n  window.cdaaas.PAGE_ANALYTICS_DATA = {"channel":"desktop","contentId":"ba3c5a72-7ed9-482e-be26-ee3d81c97bce","contentType":"home","serviceWorker":true};\n  window.cdaaas.helpers = window.cdaaas.helpers || {};\n  window.cdaaas.internals = {};\n  window.HorizonClient = new Promise((resolve, reject) => { \n    window.cdaaas.internals.resolveHorizonPromise = resolve; \n    window.cdaaas.internals.rejectHorizonPromise = reject; \n  });\n\n  window.HorizonHelpers = {\n    unloadCallbacks: [],\n  };\n\n  window.cdaaas.featureFlags = [];\n  window.cdaaas.hasFF = (ff) => window.cdaaas.featureFlags.includes(ff);\n\n  window.glbDebug = window.cdaaas.debug
# ...

# %% [markdown]
# ### Transformando o conteudo do site em uma variavel BeautifulSoup

# %%
content = response.content

site = BeautifulSoup(content , 'html.parser')

type(site)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# #### Organizando melhor a visualização do conteudo

# %%
site.prettify()
# Out:
# '<!DOCTYPE HTML>\n<html class="" lang="pt-br">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="ie=edge,chrome=1" http-equiv="x-ua-compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <script id="CDA_AAS" type="text/javascript">\n   window.cdaaas = window.cdaaas || {};\n  window.cdaaas.SETTINGS = window.cdaaas.SETTINGS || {};\n  window.cdaaas.PAGE_ANALYTICS_DATA = {"channel":"desktop","contentId":"ba3c5a72-7ed9-482e-be26-ee3d81c97bce","contentType":"home","serviceWorker":true};\n  window.cdaaas.helpers = window.cdaaas.helpers || {};\n  window.cdaaas.internals = {};\n  window.HorizonClient = new Promise((resolve, reject) => { \n    window.cdaaas.internals.resolveHorizonPromise = resolve; \n    window.cdaaas.internals.rejectHorizonPromise = reject; \n  });\n\n  window.HorizonHelpers = {\n    unloadCallbacks: [],\n  };\n\n  window.cdaaas.featureFlags = [];\n  window.cdaaas.hasFF = (ff) => window.cdaaas.featureFlags.includes(ff);\n\n  window.glbD
# ...

# %% [markdown]
# ### Extraindo a noticia

# %%
noticia = site.find('div', attrs={'class': 'feed-post bstn-item-shape type-materia'})
noticia
# Out:
# <div class="feed-post bstn-item-shape type-materia" id="9c2ae604-f739-4dde-af84-ca0b59136ac4"><div class="feed-post-body"><div class="feed-post-header"></div><div class="feed-post-body-title gui-color-primary gui-color-hover"><div class="_evt"><h2><a class="feed-post-link gui-color-primary gui-color-hover" elementtiming="text-ssr" href="https://g1.globo.com/mundo/noticia/2023/06/09/bebe-resgatada-apos-40-dias-na-amazonia-colombiana-completou-um-ano-perdida-na-mata.ghtml">Bebê fez 1 ano enquanto estava perdida na selva</a></h2></div></div><div class="feed-media-wrapper"><a class="feed-post-figure-link gui-image-hover" href="https://g1.globo.com/mundo/noticia/2023/06/09/bebe-resgatada-apos-40-dias-na-amazonia-colombiana-completou-um-ano-perdida-na-mata.ghtml"><div class="bstn-fd-item-cover"><picture class="bstn-fd-cover-picture"><img alt="Foto: (Forças Militares da Colômbia/Divulgação)" class="bstn-fd-picture-image" elementtiming="image-ssr" loading="lazy" sizes="(min-width: 540px) 50v
# ...

# %% [markdown]
# ### Extraindo o título

# %%
titulo = noticia.find('a', attrs={'class':'feed-post-link'})
titulo.text
# Out:
# 'Bebê fez 1 ano enquanto estava perdida na selva'

# %% [markdown]
# ### Extraindo o subtítulo

# %%
subtitulo = noticia.find('div', attrs={'class': 'feed-post-body-title'})
subtitulo.text
# Out:
# 'Bebê fez 1 ano enquanto estava perdida na selva'
